# %%
import h5py
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

filename = "/home/rudy/Documents/carla-dataset-runner/data/test.hdf5"

with h5py.File(filename, "r") as f:
    # List all groups
    print("Keys: %s" % f.keys())
    a_group_key = list(f.keys())[0]

    # Get the data
    data = list(f[a_group_key])
# Out:
# Keys: <KeysViewHDF5 ['depth', 'ego_speed', 'rgb', 'semantic', 'timestamps']>

# %%
dataset = h5py.File(filename, "r")

# %%
rgb_images = dataset['rgb']

# %%
first_image_key = list(rgb_images.keys())[0]
first_image = rgb_images[first_image_key]
first_image = np.array(first_image)

# %%
plt.imshow(first_image)
plt.show()
